# %%
import pandas as pd
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# CORR Kualitas Udara per KABKOT 3 Tahun

# %%
corr_ku = pd.read_csv("/Users/Jia/Downloads/data_skripsi/uji_data/merged_data_KU.csv")

# %% [markdown]
# set data corr_ku berdasarkan kabkot dan year

# %%
corr_ku['time']= pd.to_datetime(corr_ku['time'])
corr_ku = corr_ku.drop(['time'], axis=1)
corr_ku.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  180 non-null    int64
#  1   KABKOT      180 non-null    object
#  2   month       180 non-null    int64
#  3   year        180 non-null    int64
#  4   longitude   180 non-null    float64
#  5   latitude    180 non-null    float64
#  6   tb          180 non-null    int64
#  7   pm2p5       180 non-null    float64
#  8   pm10        180 non-null    float64
#  9   so2         180 non-null    float64
# dtypes: float64(5), int64(4), object(1)
# memory usage: 14.2+ KB

# %%
# filter based on KABKOT
city_east = corr_ku[corr_ku['KABKOT'] == 'JAKARTA TIMUR']
city_south = corr_ku[corr_ku['KABKOT'] == 'JAKARTA SELATAN']
city_west = corr_ku[corr_ku['KABKOT'] == 'JAKARTA BARAT']
city_north = corr_ku[corr_ku['KABKOT'] == 'JAKARTA UTARA']
city_central = corr_ku[corr_ku['KABKOT'] == 'JAKARTA PUSAT']

# %%
# extracts column names starting from the 7th column (index 6) onward
i_east = (city_east.columns[6:])
i_south = (city_south.columns[6:])
i_west = (city_west.columns[6:])
i_north = (city_north.columns[6:])
i_central = (city_central.columns[6:])
print(i_east,i_south,i_west,i_north,i_central)
# Out:
# Index(['tb', 'pm2p5', 'pm10', 'so2'], dtype='object') Index(['tb', 'pm2p5', 'pm10', 'so2'], dtype='object') Index(['tb', 'pm2p5', 'pm10', 'so2'], dtype='object') Index(['tb', 'pm2p5', 'pm10', 'so2'], dtype='object') Index(['tb', 'pm2p5', 'pm10', 'so2'], dtype='object')

# %%
#filter corr_ku based on year
ku_2020 = corr_ku[corr_ku['year'] == 2020]
ku_2021 = corr_ku[corr_ku['year'] == 2021]
ku_2022 = corr_ku[corr_ku['year'] == 2022]

# %%
# extract column names starting from the 7th column (index 6) onward
i_2020 = (ku_2020.columns[6:])
i_2021 = (ku_2021.columns[6:])
i_2022 = (ku_2022.columns[6:])
print(i_2020,i_2021,i_2022)
# Out:
# Index(['tb', 'pm2p5', 'pm10', 'so2'], dtype='object') Index(['tb', 'pm2p5', 'pm10', 'so2'], dtype='object') Index(['tb', 'pm2p5', 'pm10', 'so2'], dtype='object')

# %% [markdown]
# CORR TB AND PM 2.5 (3 year)

# %%
# Correlation between TB and PM 2.5 in DKI Jakarta
plt.figure(figsize=(10,5))
plt.title("Correlation of TB and PM 2.5")
cmap = sns.diverging_palette(260,-10,s=50, l=50, n=6, as_cmap=True) #pewarnaan

x = corr_ku['tb']
y = corr_ku['pm2p5']
correl = np.corrcoef(x, y)

sns.heatmap(correl, square=True, annot=True, linewidths=.5, cmap=cmap, vmin=-1, vmax=1)
plt.show()

# %% [markdown]
# CORR TB AND PM 10 (3 year)

# %%
# Correlation between TB and PM 10 in DKI Jakarta
plt.figure(figsize=(10,5))
plt.title("Correlation of TB and PM 10")
cmap = sns.diverging_palette(260,-10,s=50, l=50, n=6, as_cmap=True) #pewarnaan

x = corr_ku['tb']
y = corr_ku['pm10']
correl = np.corrcoef(x, y)

sns.heatmap(correl, square=True, annot=True, linewidths=.5, cmap=cmap, vmin=-1, vmax=1)
plt.show()

# %% [markdown]
# CORR TB AND SO2 (3 year)

# %%
# Correlation between TB and SO2 in DKI Jakarta
plt.figure(figsize=(10,5))
plt.title("Correlation of TB and SO2")
cmap = sns.diverging_palette(260,-10,s=50, l=50, n=6, as_cmap=True) #pewarnaan

x = corr_ku['tb']
y = corr_ku['so2']
correl = np.corrcoef(x, y)

sns.heatmap(correl, square=True, annot=True, linewidths=.5, cmap=cmap, vmin=-1, vmax=1)
plt.show()

# %% [markdown]
# CORR TB AND KU 2020 per KABKOT

# %%
corr_ku_2020 = corr_ku[corr_ku['year'] == 2020]
corr_ku_2020 = corr_ku_2020.drop(['Unnamed: 0','month', 'year','longitude', 'latitude'], axis = 1)
corr_ku_2020
# Out:
#               KABKOT   tb      pm2p5       pm10         so2
# 0      JAKARTA BARAT  715  39.201529  56.164344   75.285376
# 1      JAKARTA BARAT  803  38.279912  55.080459   69.029097
# 2      JAKARTA BARAT  689  46.589306  66.366610   91.863513
# 3      JAKARTA BARAT  359  50.980975  72.526713  107.263388
# 4      JAKARTA BARAT  276  55.668935  79.210487  120.655917
# 5      JAKARTA BARAT  353  59.317031  84.539089  117.401656
# 6      JAKARTA BARAT  335  61.032024  87.066969  123.682884
# 7      JAKARTA BARAT  260  57.818921  82.341019  109.309261
# 8      JAKARTA BARAT  284  54.832567  77.914990  103.739004
# 9      JAKARTA BARAT  241  57.304864  81.083541  101.419040
# 10     JAKARTA BARAT  249  49.371696  70.102750   93.938727
# 11     JAKARTA BARAT  227  30.068709  43.204622   66.666776
# 36     JAKARTA PUSAT  688  40.533188  58.036067   77.969973
# 37     JAKARTA PUSAT  681  39.454071  56.726724   71.045651
# 38     JAKARTA PUSAT  625  48.197478  68.643787   94.715581
# ...

# %%
corr_mat_by_stage_2020 = corr_ku_2020.groupby('KABKOT').corr()
corr_mat_by_stage_2020
# Out:
#                              tb     pm2p5      pm10       so2
# KABKOT
# JAKARTA BARAT   tb     1.000000 -0.459735 -0.453223 -0.515462
#                 pm2p5 -0.459735  1.000000  0.999870  0.944260
#                 pm10  -0.453223  0.999870  1.000000  0.945452
#                 so2   -0.515462  0.944260  0.945452  1.000000
# JAKARTA PUSAT   tb     1.000000 -0.472844 -0.466821 -0.548203
#                 pm2p5 -0.472844  1.000000  0.999866  0.940693
#                 pm10  -0.466821  0.999866  1.000000  0.942098
#                 so2   -0.548203  0.940693  0.942098  1.000000
# JAKARTA SELATAN tb     1.000000 -0.221451 -0.214796 -0.290852
#                 pm2p5 -0.221451  1.000000  0.999890  0.945722
#                 pm10  -0.214796  0.999890  1.000000  0.946962
#                 so2   -0.290852  0.945722  0.946962  1.000000
# JAKARTA TIMUR   tb     1.000000 -0.275695 -0.270447 -0.347952
#                 pm2p5 -0.275695  1.000000  0.999862  0.938919
# ...

# %% [markdown]
# ^East Jakarta in 2020

# %%
# Filter data for East Jakarta in 2020
corr_ku_2020 = corr_ku[(corr_ku['KABKOT'] == 'JAKARTA TIMUR') & (corr_ku['year'] == 2020)]

# Select relevant columns
columns_to_display = ['tb', 'pm2p5', 'pm10', 'so2']

# correlation matrix
corr_matrix = corr_ku_2020[columns_to_display].corr()

# Correlation between all variable with TB in East Jakarta 2020
plt.figure(figsize=(10, 5))
plt.title("Variables Correlation in East Jakarta 2020")
cmap = sns.diverging_palette(260, -10, s=50, l=50, n=6, as_cmap=True)  # Coloring
sns.heatmap(corr_matrix, square=True, annot=True, linewidths=.5, cmap=cmap, vmin=-1, vmax=1)
plt.show()

# %% [markdown]
# ^South Jakarta in 2020

# %%
# Filter data for South Jakarta in 2020
corr_ku_2020 = corr_ku[(corr_ku['KABKOT'] == 'JAKARTA SELATAN') & (corr_ku['year'] == 2020)]

# Select relevant columns
columns_to_display = ['tb', 'pm2p5', 'pm10', 'so2']

# correlation matrix
corr_matrix = corr_ku_2020[columns_to_display].corr()

# Correlation between all variable with TB in South Jakarta 2020
plt.figure(figsize=(10, 5))
plt.title("Variables Correlation in South Jakarta 2020")
cmap = sns.diverging_palette(260, -10, s=50, l=50, n=6, as_cmap=True)  # Coloring
sns.heatmap(corr_matrix, square=True, annot=True, linewidths=.5, cmap=cmap, vmin=-1, vmax=1)
plt.show()

# %% [markdown]
# ^West Jakarta in 2020

# %%
# Filter data for West Jakarta in 2020
corr_ku_2020 = corr_ku[(corr_ku['KABKOT'] == 'JAKARTA BARAT') & (corr_ku['year'] == 2020)]

# Select relevant columns
columns_to_display = ['tb', 'pm2p5', 'pm10', 'so2']

# correlation matrix
corr_matrix = corr_ku_2020[columns_to_display].corr()

# Correlation between all variable with TB in West Jakarta 2020
plt.figure(figsize=(10, 5))
plt.title("Variables Correlation in West Jakarta 2020")
cmap = sns.diverging_palette(260, -10, s=50, l=50, n=6, as_cmap=True)  # Coloring
sns.heatmap(corr_matrix, square=True, annot=True, linewidths=.5, cmap=cmap, vmin=-1, vmax=1)
plt.show()

# %% [markdown]
# ^North Jakarta in 2020

# %%
# Filter data for North Jakarta in 2020
corr_ku_2020 = corr_ku[(corr_ku['KABKOT'] == 'JAKARTA UTARA') & (corr_ku['year'] == 2020)]

# Select relevant columns
columns_to_display = ['tb', 'pm2p5', 'pm10', 'so2']

# correlation matrix
corr_matrix = corr_ku_2020[columns_to_display].corr()

# Correlation between all variable with TB in North Jakarta 2020
plt.figure(figsize=(10, 5))
plt.title("Variables Correlation in North Jakarta 2020")
cmap = sns.diverging_palette(260, -10, s=50, l=50, n=6, as_cmap=True)  # Coloring
sns.heatmap(corr_matrix, square=True, annot=True, linewidths=.5, cmap=cmap, vmin=-1, vmax=1)
plt.show()

# %% [markdown]
# ^Central Jakarta in 2020

# %%
# Filter data for Central Jakarta in 2020
corr_ku_2020 = corr_ku[(corr_ku['KABKOT'] == 'JAKARTA PUSAT') & (corr_ku['year'] == 2020)]

# Select relevant columns
columns_to_display = ['tb', 'pm2p5', 'pm10', 'so2']

# correlation matrix
corr_matrix = corr_ku_2020[columns_to_display].corr()

# Correlation between all variable with TB in Central Jakarta 2020
plt.figure(figsize=(10, 5))
plt.title("Variables Correlation in Central Jakarta 2020")
cmap = sns.diverging_palette(260, -10, s=50, l=50, n=6, as_cmap=True)  # Coloring
sns.heatmap(corr_matrix, square=True, annot=True, linewidths=.5, cmap=cmap, vmin=-1, vmax=1)
plt.show()

# %% [markdown]
# CORR TB AND KU 2021 per KABKOT

# %%
corr_ku_2021 = corr_ku[corr_ku['year'] == 2021]
corr_ku_2021 = corr_ku_2021.drop(['Unnamed: 0','month', 'year','longitude', 'latitude'], axis = 1)
corr_ku_2021
# Out:
#               KABKOT   tb      pm2p5       pm10         so2
# 12     JAKARTA BARAT  329  38.770220  55.754458   75.220695
# 13     JAKARTA BARAT  326  36.977892  53.218092   63.639834
# 14     JAKARTA BARAT  448  46.071524  65.535047   97.428839
# 15     JAKARTA BARAT  469  59.903050  84.901759  116.176270
# 16     JAKARTA BARAT  449  64.211863  91.328419  124.382801
# 17     JAKARTA BARAT  406  59.504222  84.523923  114.968385
# 18     JAKARTA BARAT  260  62.782235  89.350736  124.464139
# 19     JAKARTA BARAT  389  63.652269  90.285926  110.656540
# 20     JAKARTA BARAT  515  57.234407  81.076107  103.270538
# 21     JAKARTA BARAT  576  60.191038  85.212999  102.269364
# 22     JAKARTA BARAT  561  40.761925  58.225237   84.189797
# 23     JAKARTA BARAT  519  42.689377  60.820365   84.989907
# 48     JAKARTA PUSAT  371  40.178702  57.737047   78.031053
# 49     JAKARTA PUSAT  348  38.091980  54.788488   65.598722
# 50     JAKARTA PUSAT  420  47.974576  68.225756  100.706637
# ...

# %%
corr_mat_by_stage_2021 = corr_ku_2021.groupby('KABKOT').corr()
corr_mat_by_stage_2021
# Out:
#                              tb     pm2p5      pm10       so2
# KABKOT
# JAKARTA BARAT   tb     1.000000  0.010137 -0.000824 -0.020316
#                 pm2p5  0.010137  1.000000  0.999908  0.940314
#                 pm10  -0.000824  0.999908  1.000000  0.940814
#                 so2   -0.020316  0.940314  0.940814  1.000000
# JAKARTA PUSAT   tb     1.000000  0.018845  0.007574 -0.086057
#                 pm2p5  0.018845  1.000000  0.999905  0.937835
#                 pm10   0.007574  0.999905  1.000000  0.938692
#                 so2   -0.086057  0.937835  0.938692  1.000000
# JAKARTA SELATAN tb     1.000000 -0.200566 -0.210866 -0.204887
#                 pm2p5 -0.200566  1.000000  0.999921  0.943355
#                 pm10  -0.210866  0.999921  1.000000  0.944160
#                 so2   -0.204887  0.943355  0.944160  1.000000
# JAKARTA TIMUR   tb     1.000000  0.125724  0.114534  0.086646
#                 pm2p5  0.125724  1.000000  0.999901  0.937564
# ...

# %% [markdown]
# ^East Jakarta in 2021

# %%
# Filter data for East Jakarta in 2021
corr_ku_2021 = corr_ku[(corr_ku['KABKOT'] == 'JAKARTA TIMUR') & (corr_ku['year'] == 2021)]

# Select relevant columns
columns_to_display = ['tb', 'pm2p5', 'pm10', 'so2']

# correlation matrix
corr_matrix = corr_ku_2021[columns_to_display].corr()

# Correlation between all variable with TB in East Jakarta 2021
plt.figure(figsize=(10, 5))
plt.title("Variables Correlation in East Jakarta 2021")
cmap = sns.diverging_palette(260, -10, s=50, l=50, n=6, as_cmap=True)  # Coloring
sns.heatmap(corr_matrix, square=True, annot=True, linewidths=.5, cmap=cmap, vmin=-1, vmax=1)
plt.show()

# %% [markdown]
# ^South Jakarta in 2021

# %%
# Filter data for South Jakarta in 2021
corr_ku_2021 = corr_ku[(corr_ku['KABKOT'] == 'JAKARTA SELATAN') & (corr_ku['year'] == 2021)]

# Select relevant columns
columns_to_display = ['tb', 'pm2p5', 'pm10', 'so2']

# correlation matrix
corr_matrix = corr_ku_2021[columns_to_display].corr()

# Correlation between all variable with TB in South Jakarta 2021
plt.figure(figsize=(10, 5))
plt.title("Variables Correlation in South Jakarta 2021")
cmap = sns.diverging_palette(260, -10, s=50, l=50, n=6, as_cmap=True)  # Coloring
sns.heatmap(corr_matrix, square=True, annot=True, linewidths=.5, cmap=cmap, vmin=-1, vmax=1)
plt.show()

# %% [markdown]
# ^West Jakarta in 2021

# %%
# Filter data for West Jakarta in 2021
corr_ku_2021 = corr_ku[(corr_ku['KABKOT'] == 'JAKARTA BARAT') & (corr_ku['year'] == 2021)]

# Select relevant columns
columns_to_display = ['tb', 'pm2p5', 'pm10', 'so2']

# correlation matrix
corr_matrix = corr_ku_2021[columns_to_display].corr()

# Correlation between all variable with TB in West Jakarta 2021
plt.figure(figsize=(10, 5))
plt.title("Variables Correlation in West Jakarta 2021")
cmap = sns.diverging_palette(260, -10, s=50, l=50, n=6, as_cmap=True)  # Coloring
sns.heatmap(corr_matrix, square=True, annot=True, linewidths=.5, cmap=cmap, vmin=-1, vmax=1)
plt.show()

# %% [markdown]
# ^North Jakarta in 2021

# %%
# Filter data for North Jakarta in 2021
corr_ku_2021 = corr_ku[(corr_ku['KABKOT'] == 'JAKARTA UTARA') & (corr_ku['year'] == 2021)]

# Select relevant columns
columns_to_display = ['tb', 'pm2p5', 'pm10', 'so2']

# correlation matrix
corr_matrix = corr_ku_2021[columns_to_display].corr()

# Correlation between all variable with TB in North Jakarta 2021
plt.figure(figsize=(10, 5))
plt.title("Variables Correlation in North Jakarta 2021")
cmap = sns.diverging_palette(260, -10, s=50, l=50, n=6, as_cmap=True)  # Coloring
sns.heatmap(corr_matrix, square=True, annot=True, linewidths=.5, cmap=cmap, vmin=-1, vmax=1)
plt.show()

# %% [markdown]
# ^Central Jakarta in 2021

# %%
# Filter data for Central Jakarta in 2021
corr_ku_2021 = corr_ku[(corr_ku['KABKOT'] == 'JAKARTA PUSAT') & (corr_ku['year'] == 2021)]

# Select relevant columns
columns_to_display = ['tb', 'pm2p5', 'pm10', 'so2']

# correlation matrix
corr_matrix = corr_ku_2021[columns_to_display].corr()

# Correlation between all variable with TB in Central Jakarta 2021
plt.figure(figsize=(10, 5))
plt.title("Variables Correlation in Central Jakarta 2021")
cmap = sns.diverging_palette(260, -10, s=50, l=50, n=6, as_cmap=True)  # Coloring
sns.heatmap(corr_matrix, square=True, annot=True, linewidths=.5, cmap=cmap, vmin=-1, vmax=1)
plt.show()

# %% [markdown]
# CORR TB AND KU 2022 per KABKOT

# %%
corr_ku_2022 = corr_ku[corr_ku['year'] == 2022]
corr_ku_2022 = corr_ku_2022.drop(['Unnamed: 0','month', 'year','longitude', 'latitude'], axis = 1)
corr_ku_2022
# Out:
#               KABKOT    tb      pm2p5       pm10         so2
# 24     JAKARTA BARAT   851  40.907131  57.999436   78.397712
# 25     JAKARTA BARAT   457  43.454320  61.461500   74.460298
# 26     JAKARTA BARAT   655  48.806472  68.619932   95.496654
# 27     JAKARTA BARAT   698  52.900781  74.814717  109.070570
# 28     JAKARTA BARAT   650  58.325385  82.926960  123.263528
# 29     JAKARTA BARAT   881  63.359767  90.111428  120.846046
# 30     JAKARTA BARAT   829  63.042981  89.779119  123.379673
# 31     JAKARTA BARAT   864  65.014947  92.400352  114.230735
# 32     JAKARTA BARAT   891  64.442884  91.663546  106.868705
# 33     JAKARTA BARAT   898  50.677753  71.979880   96.953512
# 34     JAKARTA BARAT   999  47.206048  67.313310   93.549573
# 35     JAKARTA BARAT   933  39.095236  56.019231   78.387146
# 60     JAKARTA PUSAT   866  42.582045  60.361643   81.396304
# 61     JAKARTA PUSAT   378  45.010139  63.673341   76.908537
# ...

# %%
corr_mat_by_stage_2022 = corr_ku_2022.groupby('KABKOT').corr()
corr_mat_by_stage_2022
# Out:
#                              tb     pm2p5      pm10       so2
# KABKOT
# JAKARTA BARAT   tb     1.000000  0.135476  0.150454  0.110480
#                 pm2p5  0.135476  1.000000  0.999738  0.905070
#                 pm10   0.150454  0.999738  1.000000  0.905089
#                 so2    0.110480  0.905070  0.905089  1.000000
# JAKARTA PUSAT   tb     1.000000 -0.127199 -0.118773 -0.167837
#                 pm2p5 -0.127199  1.000000  0.999723  0.901605
#                 pm10  -0.118773  0.999723  1.000000  0.901683
#                 so2   -0.167837  0.901605  0.901683  1.000000
# JAKARTA SELATAN tb     1.000000 -0.061904 -0.050777 -0.142853
#                 pm2p5 -0.061904  1.000000  0.999777  0.907132
#                 pm10  -0.050777  0.999777  1.000000  0.907099
#                 so2   -0.142853  0.907132  0.907099  1.000000
# JAKARTA TIMUR   tb     1.000000  0.044258  0.056925  0.012267
#                 pm2p5  0.044258  1.000000  0.999715  0.899809
# ...

# %% [markdown]
# ^East Jakarta in 2022

# %%
# Filter data for East Jakarta in 2022
corr_ku_2022 = corr_ku[(corr_ku['KABKOT'] == 'JAKARTA TIMUR') & (corr_ku['year'] == 2022)]

# Select relevant columns
columns_to_display = ['tb', 'pm2p5', 'pm10', 'so2']

# correlation matrix
corr_matrix = corr_ku_2022[columns_to_display].corr()

# Correlation between all variable with TB in East Jakarta 2022
plt.figure(figsize=(10, 5))
plt.title("Variables Correlation in East Jakarta 2022")
cmap = sns.diverging_palette(260, -10, s=50, l=50, n=6, as_cmap=True)  # Coloring
sns.heatmap(corr_matrix, square=True, annot=True, linewidths=.5, cmap=cmap, vmin=-1, vmax=1)
plt.show()

# %% [markdown]
# ^South Jakarta in 2022

# %%
# Filter data for South Jakarta in 2022
corr_ku_2022 = corr_ku[(corr_ku['KABKOT'] == 'JAKARTA SELATAN') & (corr_ku['year'] == 2022)]

# Select relevant columns
columns_to_display = ['tb', 'pm2p5', 'pm10', 'so2']

# correlation matrix
corr_matrix = corr_ku_2022[columns_to_display].corr()

# Correlation between all variable with TB in South Jakarta 2022
plt.figure(figsize=(10, 5))
plt.title("Variables Correlation in South Jakarta 2022")
cmap = sns.diverging_palette(260, -10, s=50, l=50, n=6, as_cmap=True)  # Coloring
sns.heatmap(corr_matrix, square=True, annot=True, linewidths=.5, cmap=cmap, vmin=-1, vmax=1)
plt.show()

# %% [markdown]
# ^West Jakarta in 2022

# %%
# Filter data for West Jakarta in 2022
corr_ku_2022 = corr_ku[(corr_ku['KABKOT'] == 'JAKARTA BARAT') & (corr_ku['year'] == 2022)]

# Select relevant columns
columns_to_display = ['tb', 'pm2p5', 'pm10', 'so2']

# correlation matrix
corr_matrix = corr_ku_2022[columns_to_display].corr()

# Correlation between all variable with TB in West Jakarta 2022
plt.figure(figsize=(10, 5))
plt.title("Variables Correlation in West Jakarta 2022")
cmap = sns.diverging_palette(260, -10, s=50, l=50, n=6, as_cmap=True)  # Coloring
sns.heatmap(corr_matrix, square=True, annot=True, linewidths=.5, cmap=cmap, vmin=-1, vmax=1)
plt.show()

# %% [markdown]
# ^North Jakarta in 2022

# %%
# Filter data for North Jakarta in 2022
corr_ku_2022 = corr_ku[(corr_ku['KABKOT'] == 'JAKARTA UTARA') & (corr_ku['year'] == 2022)]

# Select relevant columns
columns_to_display = ['tb', 'pm2p5', 'pm10', 'so2']

# correlation matrix
corr_matrix = corr_ku_2022[columns_to_display].corr()

# Correlation between all variable with TB in North Jakarta 2022
plt.figure(figsize=(10, 5))
plt.title("Variables Correlation in North Jakarta 2022")
cmap = sns.diverging_palette(260, -10, s=50, l=50, n=6, as_cmap=True)  # Coloring
sns.heatmap(corr_matrix, square=True, annot=True, linewidths=.5, cmap=cmap, vmin=-1, vmax=1)
plt.show()

# %% [markdown]
# ^Central Jakarta in 2022

# %%
# Filter data for Central Jakarta in 2022
corr_ku_2022 = corr_ku[(corr_ku['KABKOT'] == 'JAKARTA PUSAT') & (corr_ku['year'] == 2022)]

# Select relevant columns
columns_to_display = ['tb', 'pm2p5', 'pm10', 'so2']

# correlation matrix
corr_matrix = corr_ku_2022[columns_to_display].corr()

# Correlation between all variable with TB in Central Jakarta 2022
plt.figure(figsize=(10, 5))
plt.title("Variables Correlation in Central Jakarta 2022")
cmap = sns.diverging_palette(260, -10, s=50, l=50, n=6, as_cmap=True)  # Coloring
sns.heatmap(corr_matrix, square=True, annot=True, linewidths=.5, cmap=cmap, vmin=-1, vmax=1)
plt.show()
