# %%
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt
import xlrd

# %%
df_excel = pd.read_excel('/Users/Jia/Downloads/data_skripsi/tb/data_tb.xlsx')

# %% [markdown]
# Convert Datetime (TB)

# %%
# Mengonversi kolom 'time' ke tipe data datetime
df_excel['time'] = pd.to_datetime(df_excel['time'])

# Menambahkan kolom 'month'
df_excel['month'] = df_excel['time'].dt.month

# Menambahkan kolom 'year'
df_excel['year'] = df_excel['time'].dt.year

# %%
df_excel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   KABKOT     180 non-null    object
#  1   month      180 non-null    int32
#  2   year       180 non-null    int32
#  3   tb         180 non-null    int64
#  4   longitude  180 non-null    float64
#  5   latitude   180 non-null    float64
#  6   time       180 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), int32(2), int64(1), object(1)
# memory usage: 8.6+ KB

# %% [markdown]
# Merapihkan Data TB 2020-2023

# %%
import calendar

# %%
# Filter for years 2020-2022
df_tb = df_excel[(df_excel['year'] >= 2020) & (df_excel['year'] <= 2022)]

# Group tb_total by KABKOT, month, and time
tb_total = df_tb.groupby(['KABKOT', 'month', 'time'])['tb'].sum()
tb_total
# Out:
# KABKOT         month  time
# JAKARTA BARAT  1      2020-01-01    715
#                       2021-01-01    329
#                       2022-01-01    851
#                2      2020-02-01    803
#                       2021-02-01    326
#                                    ...
# JAKARTA UTARA  11     2021-11-01    475
#                       2022-11-01    685
#                12     2020-12-01    201
#                       2021-12-01    450
#                       2022-12-01    671
# Name: tb, Length: 180, dtype: int64

# %% [markdown]
# Merapihkan Data Curah Hujan (tp) 2020-2023

# %%
df_tp = pd.read_csv(r'/Users/Jia/Downloads/data_skripsi/curah_hujan/dissolved_result_tp_3years.csv')
df_tp = df_tp.drop(['Unnamed: 0'], axis=1)
print(df_tp.columns)
# Out:
# Index(['KABKOT', 'month', 'year', 'longitude', 'latitude', 'tp', 'time'], dtype='object')

# %%
# Filter for years 2020-2022
df_tp = df_tp[(df_tp['year'] >= 2020) & (df_tp['year'] <= 2022)]

# Group tp_mean by KABKOT, month, and time
tp_mean = df_tp.groupby(['KABKOT', 'month', 'time'])['tp'].mean()
tp_mean
# Out:
# KABKOT         month  time
# JAKARTA BARAT  1      2020-01-01    14.475730
#                       2021-01-01    10.499982
#                       2022-01-01     6.211204
#                2      2020-02-01    13.691263
#                       2021-02-01    14.319914
#                                       ...
# JAKARTA UTARA  11     2021-11-01     8.136556
#                       2022-11-01     5.543476
#                12     2020-12-01     9.142884
#                       2021-12-01     8.356443
#                       2022-12-01     7.970700
# Name: tp, Length: 180, dtype: float64

# %% [markdown]
# Merge Files

# %%
# Merge DataFrames on 'KABKOT', 'month', and 'time'
df_tb_tp = pd.merge(tb_total, tp_mean, on=['KABKOT', 'month'])
df_tb_tp
# Out:
#                       tb         tp
# KABKOT        month
# JAKARTA BARAT 1      715  14.475730
#               1      715  10.499982
#               1      715   6.211204
#               1      329  14.475730
#               1      329  10.499982
# ...                  ...        ...
# JAKARTA UTARA 12     450   8.356443
#               12     450   7.970700
#               12     671   9.142884
#               12     671   8.356443
#               12     671   7.970700
#
# [540 rows x 2 columns]

# %%
df_tb_tp = df_tb_tp.groupby(['KABKOT', 'month']).agg({'tb':'sum', 'tp':'mean'}).reset_index()
# reset_index() untuk memisahkan kolom KABKOT dan month

# %%
df_tb_tp
# Out:
#              KABKOT  month    tb         tp
# 0     JAKARTA BARAT      1  5685  10.395638
# 1     JAKARTA BARAT      2  4758  11.534759
# 2     JAKARTA BARAT      3  5376   7.887169
# 3     JAKARTA BARAT      4  4578   6.262651
# 4     JAKARTA BARAT      5  4125   4.730499
# 5     JAKARTA BARAT      6  4920   3.903356
# 6     JAKARTA BARAT      7  4272   2.862057
# 7     JAKARTA BARAT      8  4539   3.170703
# 8     JAKARTA BARAT      9  5070   4.081026
# 9     JAKARTA BARAT     10  5145   6.336498
# 10    JAKARTA BARAT     11  5427   5.994847
# 11    JAKARTA BARAT     12  5037   8.104786
# 12    JAKARTA PUSAT      1  5775  10.895477
# 13    JAKARTA PUSAT      2  4221  12.036821
# 14    JAKARTA PUSAT      3  4869   8.158352
# 15    JAKARTA PUSAT      4  3981   6.472333
# 16    JAKARTA PUSAT      5  3579   4.739718
# 17    JAKARTA PUSAT      6  4167   3.887330
# 18    JAKARTA PUSAT      7  3810   2.637048
# 19    JAKARTA PUSAT      8  4242   3.104376
# 20    JAKARTA PUSAT      9  4515   3.981271
# 21    JAKARTA PUSAT     10  4548   6.741920
# 22    JAKARTA PUSAT     11  4572   6.833146
# 23    JAKARTA PUSAT     12  4434   8.465527
# 24  JAKARTA SELATAN      1  5691  10.804068
# 25  JAKARTA SELATAN      2  4320  11.597090
# 26  JAKARTA SELATAN      3  5205   8.646220
# 27  JAKARTA SELATAN      4  4611   6.853737
# 28  JAKARTA SELATAN      5  3795   4.882709
# 29  JAKARTA SELATAN      6  4920   4.004005
# 30  JAKARTA SELATAN      7  4458   2.795675
# 31  JAKARTA SELATAN      8  4653   3.538497
# 32  JAKARTA SELATAN      9  5199   4.566998
# 33  JAKARTA SELATAN     10  4980   7.490197
# 34  JAKARTA SELATAN     11  5142   7.382625
# 35  JAKARTA SELATAN     12  5154   8.676168
# 36    JAKARTA TIMUR      1  7437  11.350539
# 37    JAKARTA TIMUR      2  5949  12.270698
# 38    JAKARTA TIMUR      3  7809   8.838295
# 39    JAKARTA TIMUR      4  7101   6.983751
# 40    JAKARTA TIMUR      5  5958   4.973592
# 41    JAKARTA TIMUR      6  7458   4.054082
# 42    JAKARTA TIMUR      7  6303   2.562174
# 43    JAKARTA TIMUR      8  6822   3.215075
# 44    JAKARTA TIMUR      9  7641   4.237223
# 45    JAKARTA TIMUR     10  7803   7.523619
# 46    JAKARTA TIMUR     11  7650   7.899883
# 47    JAKARTA TIMUR     12  7467   8.960145
# 48    JAKARTA UTARA      1  4599  10.957898
# 49    JAKARTA UTARA      2  3207  12.396447
# 50    JAKARTA UTARA      3  4041   7.763281
# 51    JAKARTA UTARA      4  3657   6.218471
# 52    JAKARTA UTARA      5  3195   4.774179
# 53    JAKARTA UTARA      6  3492   3.925856
# 54    JAKARTA UTARA      7  3246   2.564369
# 55    JAKARTA UTARA      8  3633   2.761607
# 56    JAKARTA UTARA      9  4038   3.718347
# 57    JAKARTA UTARA     10  3960   6.214897
# 58    JAKARTA UTARA     11  4065   6.357653
# 59    JAKARTA UTARA     12  3966   8.490009

# %%
df_tb_tp.shape
# Out:
# (60, 4)

# %% [markdown]
# Datetime edit for 'month'

# %%
import calendar

# Format for monthly graph
df_tb_tp['month'] = pd.to_datetime(df_tb_tp['month'], format='%m').dt.month_name()

# Set the ['month_name'] as an index
df_tb_tp = df_tb_tp.set_index('month').reset_index()

# %%
df_tb_tp
# Out:
#         month           KABKOT    tb         tp
# 0     January    JAKARTA BARAT  5685  10.395638
# 1    February    JAKARTA BARAT  4758  11.534759
# 2       March    JAKARTA BARAT  5376   7.887169
# 3       April    JAKARTA BARAT  4578   6.262651
# 4         May    JAKARTA BARAT  4125   4.730499
# 5        June    JAKARTA BARAT  4920   3.903356
# 6        July    JAKARTA BARAT  4272   2.862057
# 7      August    JAKARTA BARAT  4539   3.170703
# 8   September    JAKARTA BARAT  5070   4.081026
# 9     October    JAKARTA BARAT  5145   6.336498
# 10   November    JAKARTA BARAT  5427   5.994847
# 11   December    JAKARTA BARAT  5037   8.104786
# 12    January    JAKARTA PUSAT  5775  10.895477
# 13   February    JAKARTA PUSAT  4221  12.036821
# 14      March    JAKARTA PUSAT  4869   8.158352
# 15      April    JAKARTA PUSAT  3981   6.472333
# 16        May    JAKARTA PUSAT  3579   4.739718
# 17       June    JAKARTA PUSAT  4167   3.887330
# 18       July    JAKARTA PUSAT  3810   2.637048
# 19     August    JAKARTA PUSAT  4242   3.104376
# 20  September    JAKARTA PUSAT  4515   3.981271
# 21    October    JAKARTA PUSAT  4548   6.741920
# 22   November    JAKARTA PUSAT  4572   6.833146
# 23   December    JAKARTA PUSAT  4434   8.465527
# 24    January  JAKARTA SELATAN  5691  10.804068
# 25   February  JAKARTA SELATAN  4320  11.597090
# 26      March  JAKARTA SELATAN  5205   8.646220
# 27      April  JAKARTA SELATAN  4611   6.853737
# 28        May  JAKARTA SELATAN  3795   4.882709
# 29       June  JAKARTA SELATAN  4920   4.004005
# 30       July  JAKARTA SELATAN  4458   2.795675
# 31     August  JAKARTA SELATAN  4653   3.538497
# 32  September  JAKARTA SELATAN  5199   4.566998
# 33    October  JAKARTA SELATAN  4980   7.490197
# 34   November  JAKARTA SELATAN  5142   7.382625
# 35   December  JAKARTA SELATAN  5154   8.676168
# 36    January    JAKARTA TIMUR  7437  11.350539
# 37   February    JAKARTA TIMUR  5949  12.270698
# 38      March    JAKARTA TIMUR  7809   8.838295
# 39      April    JAKARTA TIMUR  7101   6.983751
# 40        May    JAKARTA TIMUR  5958   4.973592
# 41       June    JAKARTA TIMUR  7458   4.054082
# 42       July    JAKARTA TIMUR  6303   2.562174
# 43     August    JAKARTA TIMUR  6822   3.215075
# 44  September    JAKARTA TIMUR  7641   4.237223
# 45    October    JAKARTA TIMUR  7803   7.523619
# 46   November    JAKARTA TIMUR  7650   7.899883
# 47   December    JAKARTA TIMUR  7467   8.960145
# 48    January    JAKARTA UTARA  4599  10.957898
# 49   February    JAKARTA UTARA  3207  12.396447
# 50      March    JAKARTA UTARA  4041   7.763281
# 51      April    JAKARTA UTARA  3657   6.218471
# 52        May    JAKARTA UTARA  3195   4.774179
# 53       June    JAKARTA UTARA  3492   3.925856
# 54       July    JAKARTA UTARA  3246   2.564369
# 55     August    JAKARTA UTARA  3633   2.761607
# 56  September    JAKARTA UTARA  4038   3.718347
# 57    October    JAKARTA UTARA  3960   6.214897
# 58   November    JAKARTA UTARA  4065   6.357653
# 59   December    JAKARTA UTARA  3966   8.490009

# %% [markdown]
# Overlay layer plot for TB and TP

# %%
indicators = ['tb', 'tp']

# Group data by KABKOT
grouped_data = df_tb_tp.groupby('KABKOT')

# Plot time series for 'tb' and 'so2' for each KABKOT
fig, axs = plt.subplots(len(grouped_data), 1, figsize=(20, len(grouped_data)*5), sharex=False, gridspec_kw={'hspace': 0.2})


for (name, group), ax in zip(grouped_data, axs):
    x = group['month']
    y1 = group['tb']
    y2 = group['tp']

    ax.plot(x, y1, label='Kejadian Tuberkulosis', marker='o', color='darkcyan')
    ax.set_ylabel(f'Jumlah Kejadian Tuberkulosis (jiwa)', color='darkcyan')
    ax.tick_params(axis='y', labelcolor='darkcyan')

    ax2 = ax.twinx()
    ax2.plot(x, y2, label='Curah Hujan', marker='o', color='brown')
    ax2.set_ylabel(f'Rata-Rata Curah Hujan (mm)', color='brown')
    ax2.tick_params(axis='y', labelcolor='brown')

    ax.legend(loc= 'upper left', fontsize=16)
    ax2.legend(loc= 'upper right', fontsize=16)
    
# Add common x-axis label
axs[-1].set_xlabel('Month', fontsize= 14)
axs[-1].set_title('JAKARTA UTARA', fontsize= 14)
axs[-2].set_title('JAKARTA TIMUR',fontsize= 14)
axs[-3].set_title('JAKARTA SELATAN', fontsize= 14)
axs[-4].set_title('JAKARTA PUSAT', fontsize= 14)
axs[-5].set_title('JAKARTA BARAT', fontsize= 14)

plt.show()
